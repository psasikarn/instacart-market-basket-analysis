# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sample_order = pd.read_csv("instacart/sample_order.csv")

# %%
sample_order = sample_order.sort_values(by=['user_id', 'order_number']).reset_index(drop=True)
sample_order
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         1374495        3    prior             1          1
# 1         1374495        3    prior             1          1
# 2         1374495        3    prior             1          1
# 3         1374495        3    prior             1          1
# 4         1374495        3    prior             1          1
# ...           ...      ...      ...           ...        ...
# 8246811   1716008   206205    train             4          1
# 8246812   1716008   206205    train             4          1
# 8246813   1716008   206205    train             4          1
# 8246814   1716008   206205    train             4          1
# 8246815   1716008   206205    train             4          1
#
#          order_hour_of_day  days_since_prior_order  product_id  \
# 0                       14                     NaN      9387.0
# 1                       14                     NaN     17668.0
# 2                       14                     NaN     15143.0
# 3                       14                     NaN     16797.0
# 4                       14                     NaN     39190.0
# ...                    ...                     ...         ...
# 8246811                 16                    10.0     42495.0
# 8246812                 16                    10.0     10181.0
# 8246813                 16                    10.0      1158.0
# 8246814                 16                    10.0     29499.0
# 8246815                 16                    10.0     16174.0
#
#          add_to_cart_order  reordered  \
# 0                      1.0        0.0
# 1                      2.0        0.0
# 2                      3.0        0.0
# 3                      4.0        0.0
# 4                      5.0        0.0
# ...                    ...        ...
# 8246811               15.0        0.0
# 8246812               16.0        1.0
# 8246813               17.0        0.0
# 8246814               18.0        0.0
# 8246815               19.0        0.0
#
#                                             product_name  aisle_id  \
# 0                                    Granny Smith Apples      24.0
# 1        Unsweetened Chocolate Almond Breeze Almond Milk      91.0
# 2                                         Blueberry Pint      24.0
# 3                                           Strawberries      24.0
# 4                        Vanilla Unsweetened Almond Milk      91.0
# ...                                                  ...       ...
# 8246811                         Pink Lady (Cripps) Apple      24.0
# 8246812                                Classic Guacamole      67.0
# 8246813                                     Mango Chunks     116.0
# 8246814                                   Ghee, Original      76.0
# 8246815    Original Vegenaise Dressing & Sandwich Spread      72.0
#
#          department_id                 aisle     department
# 0                  4.0          fresh fruits        produce
# 1                 16.0       soy lactosefree     dairy eggs
# 2                  4.0          fresh fruits        produce
# 3                  4.0          fresh fruits        produce
# 4                 16.0       soy lactosefree     dairy eggs
# ...                ...                   ...            ...
# 8246811            4.0          fresh fruits        produce
# 8246812           20.0  fresh dips tapenades           deli
# 8246813            1.0        frozen produce         frozen
# 8246814            6.0          indian foods  international
# 8246815           13.0            condiments         pantry
#
# [8246816 rows x 15 columns]

# %%
sample_order.groupby(['user_id'])['eval_set'].last().value_counts()
# Out:
# train    31806
# test     18194
# Name: eval_set, dtype: int64

# %% [markdown]
# ## Cumsum of days since prior order
# - used for creating the feature "days since last bought of this product"

# %%
orders = pd.read_csv("instacart/orders.csv")
orders = orders.sort_values(by=['user_id','order_number']).reset_index(drop=True)
orders.head(20)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# 11   2168274        2    prior             1          2                 11
# 12   1501582        2    prior             2          5                 10
# 13   1901567        2    prior             3          1                 10
# 14    738281        2    prior             4          2                 10
# 15   1673511        2    prior             5          3                 11
# 16   1199898        2    prior             6          2                  9
# 17   3194192        2    prior             7          2                 12
# 18    788338        2    prior             8          1                 15
# 19   1718559        2    prior             9          2                  9
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# 5                     19.0
# 6                     20.0
# 7                     14.0
# 8                      0.0
# 9                     30.0
# 10                    14.0
# 11                     NaN
# 12                    10.0
# 13                     3.0
# 14                     8.0
# 15                     8.0
# 16                    13.0
# 17                    14.0
# 18                    27.0
# 19                     8.0

# %%
orders.groupby('user_id')['days_since_prior_order'].cumsum()
# Out:
# 0            NaN
# 1           15.0
# 2           36.0
# 3           65.0
# 4           93.0
#            ...
# 3421078    155.0
# 3421079    185.0
# 3421080    203.0
# 3421081    210.0
# 3421082    240.0
# Name: days_since_prior_order, Length: 3421083, dtype: float64

# %%
orders['days_cumsum'] = orders.groupby('user_id')['days_since_prior_order'].cumsum()

# %%
sample_order = sample_order.merge(orders[['order_id', 'days_cumsum']], how='left', on='order_id')
sample_order.head(30)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    1374495        3    prior             1          1                 14
# 1    1374495        3    prior             1          1                 14
# 2    1374495        3    prior             1          1                 14
# 3    1374495        3    prior             1          1                 14
# 4    1374495        3    prior             1          1                 14
# 5    1374495        3    prior             1          1                 14
# 6    1374495        3    prior             1          1                 14
# 7    1374495        3    prior             1          1                 14
# 8    1374495        3    prior             1          1                 14
# 9    1374495        3    prior             1          1                 14
# 10    444309        3    prior             2          3                 19
# 11    444309        3    prior             2          3                 19
# 12    444309        3    prior             2          3                 19
# 13    444309        3    prior             2          3                 19
# 14    444309        3    prior             2          3                 19
# 15    444309        3    prior             2          3                 19
# 16    444309        3    prior             2          3                 19
# 17    444309        3    prior             2          3                 19
# 18    444309        3    prior             2          3                 19
# 19   3002854        3    prior             3          3                 16
# 20   3002854        3    prior             3          3                 16
# 21   3002854        3    prior             3          3                 16
# 22   3002854        3    prior             3          3                 16
# 23   3002854        3    prior             3          3                 16
# 24   3002854        3    prior             3          3                 16
# 25   2037211        3    prior             4          2                 18
# 26   2037211        3    prior             4          2                 18
# 27   2037211        3    prior             4          2                 18
# 28   2037211        3    prior             4          2                 18
# 29   2037211        3    prior             4          2                 18
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN      9387.0                1.0        0.0
# 1                      NaN     17668.0                2.0        0.0
# 2                      NaN     15143.0                3.0        0.0
# 3                      NaN     16797.0                4.0        0.0
# 4                      NaN     39190.0                5.0        0.0
# 5                      NaN     47766.0                6.0        0.0
# 6                      NaN     21903.0                7.0        0.0
# 7                      NaN     39922.0                8.0        0.0
# 8                      NaN     24810.0                9.0        0.0
# 9                      NaN     32402.0               10.0        0.0
# 10                     9.0     38596.0                1.0        0.0
# 11                     9.0     21903.0                2.0        1.0
# 12                     9.0       248.0                3.0        0.0
# 13                     9.0     40604.0                4.0        0.0
# 14                     9.0      8021.0                5.0        0.0
# 15                     9.0     17668.0                6.0        1.0
# 16                     9.0     21137.0                7.0        0.0
# 17                     9.0     23650.0                8.0        0.0
# 18                     9.0     32402.0                9.0        1.0
# 19                    21.0     39190.0                1.0        1.0
# 20                    21.0     47766.0                2.0        1.0
# 21                    21.0     21903.0                3.0        1.0
# 22                    21.0     49683.0                4.0        0.0
# 23                    21.0     28373.0                5.0        0.0
# 24                    21.0      7503.0                6.0        0.0
# 25                    20.0      1819.0                1.0        0.0
# 26                    20.0     12845.0                2.0        0.0
# 27                    20.0      9387.0                3.0        1.0
# 28                    20.0     16965.0                4.0        0.0
# 29                    20.0     24010.0                5.0        0.0
#
#                                        product_name  aisle_id  department_id  \
# 0                               Granny Smith Apples      24.0            4.0
# 1   Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 2                                    Blueberry Pint      24.0            4.0
# 3                                      Strawberries      24.0            4.0
# 4                   Vanilla Unsweetened Almond Milk      91.0           16.0
# 5                                   Organic Avocado      24.0            4.0
# 6                              Organic Baby Spinach     123.0            4.0
# 7                                     Celery Sticks     123.0            4.0
# 8           Organic Lightly Salted Brown Rice Cakes      78.0           19.0
# 9                         Crackers, Crispy, Cheddar      78.0           19.0
# 10                         Part Skim Ricotta Cheese     108.0           16.0
# 11                             Organic Baby Spinach     123.0            4.0
# 12                      Dried Sweetened Cranberries     117.0           19.0
# 13                             Feta Cheese Crumbles      21.0           16.0
# 14                       100% Recycled Paper Towels      54.0           17.0
# 15  Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 16                             Organic Strawberries      24.0            4.0
# 17                                Electrolyte Water     115.0            7.0
# 18                        Crackers, Crispy, Cheddar      78.0           19.0
# 19                  Vanilla Unsweetened Almond Milk      91.0           16.0
# 20                                  Organic Avocado      24.0            4.0
# 21                             Organic Baby Spinach     123.0            4.0
# 22                                   Cucumber Kirby      83.0            4.0
# 23                      Original Rotisserie Chicken      13.0           20.0
# 24                                    Whole Almonds     117.0           19.0
# 25         All Natural No Stir Creamy Almond Butter      88.0           13.0
# 26                                  Chopped Walnuts     117.0           19.0
# 27                              Granny Smith Apples      24.0            4.0
# 28                              Chocolate Ice Cream      37.0            1.0
# 29                        Wheat Gluten Free Waffles      52.0            1.0
#
#                             aisle  department  days_cumsum
# 0                    fresh fruits     produce          NaN
# 1                 soy lactosefree  dairy eggs          NaN
# 2                    fresh fruits     produce          NaN
# 3                    fresh fruits     produce          NaN
# 4                 soy lactosefree  dairy eggs          NaN
# 5                    fresh fruits     produce          NaN
# 6      packaged vegetables fruits     produce          NaN
# 7      packaged vegetables fruits     produce          NaN
# 8                        crackers      snacks          NaN
# 9                        crackers      snacks          NaN
# 10           other creams cheeses  dairy eggs          9.0
# 11     packaged vegetables fruits     produce          9.0
# 12         nuts seeds dried fruit      snacks          9.0
# 13                packaged cheese  dairy eggs          9.0
# 14                    paper goods   household          9.0
# 15                soy lactosefree  dairy eggs          9.0
# 16                   fresh fruits     produce          9.0
# 17  water seltzer sparkling water   beverages          9.0
# 18                       crackers      snacks          9.0
# 19                soy lactosefree  dairy eggs         30.0
# 20                   fresh fruits     produce         30.0
# 21     packaged vegetables fruits     produce         30.0
# 22               fresh vegetables     produce         30.0
# 23                 prepared meals        deli         30.0
# 24         nuts seeds dried fruit      snacks         30.0
# 25                        spreads      pantry         50.0
# 26         nuts seeds dried fruit      snacks         50.0
# 27                   fresh fruits     produce         50.0
# 28                  ice cream ice      frozen         50.0
# 29               frozen breakfast      frozen         50.0

# %%
# set the first order to have days_cumsum = 0
sample_order['days_cumsum'] = sample_order['days_cumsum'].fillna(0)

# %% [markdown]
# ## Split prior, train, test

# %%
sample_order_test = sample_order[sample_order['eval_set']=='test']
sample_order_train = sample_order[sample_order['eval_set']=='train']
sample_order_prior = sample_order[sample_order['eval_set']=='prior']

# %%
sample_order_prior.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  7.889718e+06  7.889718e+06  7.889718e+06  7.889718e+06
# mean   1.708635e+06  1.033913e+05  1.702371e+01  2.730074e+00
# std    9.877101e+05  5.978487e+04  1.734933e+01  2.085583e+00
# min    3.000000e+00  3.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.528170e+05  5.146700e+04  5.000000e+00  1.000000e+00
# 50%    1.708149e+06  1.034330e+05  1.100000e+01  3.000000e+00
# 75%    2.564160e+06  1.554300e+05  2.400000e+01  5.000000e+00
# max    3.421080e+06  2.062050e+05  9.900000e+01  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       7.889718e+06            7.385777e+06  7.889718e+06
# mean        1.341255e+01            1.112729e+01  2.557857e+04
# std         4.246393e+00            8.791116e+00  1.409077e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# 25%         1.000000e+01            5.000000e+00  1.353500e+04
# 50%         1.300000e+01            8.000000e+00  2.523700e+04
# 75%         1.600000e+01            1.500000e+01  3.791700e+04
# max         2.300000e+01            3.000000e+01  4.968800e+04
#
#        add_to_cart_order     reordered      aisle_id  department_id  \
# count       7.889718e+06  7.889718e+06  7.889718e+06   7.889718e+06
# mean        8.358219e+00  5.903843e-01  7.123248e+01   9.928046e+00
# std         7.119127e+00  4.917629e-01  3.820952e+01   6.280409e+00
# min         1.000000e+00  0.000000e+00  1.000000e+00   1.000000e+00
# 25%         3.000000e+00  0.000000e+00  3.100000e+01   4.000000e+00
# 50%         6.000000e+00  1.000000e+00  8.300000e+01   9.000000e+00
# 75%         1.100000e+01  1.000000e+00  1.070000e+02   1.600000e+01
# max         1.450000e+02  1.000000e+00  1.340000e+02   2.100000e+01
#
#         days_cumsum
# count  7.889718e+06
# mean   1.237188e+02
# std    9.662032e+01
# min    0.000000e+00
# 25%    4.100000e+01
# 50%    1.030000e+02
# 75%    1.940000e+02
# max    3.650000e+02

# %%
# user_id = 3 bought product_id = 1819 multiple times
sample_order_prior = sample_order_prior.sort_values(by=['user_id', 'product_id', 'order_number']).reset_index(drop=True)
sample_order_prior
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0          444309        3    prior             2          3
# 1          676467        3    prior            10          3
# 2         2037211        3    prior             4          2
# 3         1972919        3    prior             6          0
# 4         1839752        3    prior             7          0
# ...           ...      ...      ...           ...        ...
# 7889713    414137   206205    prior             3          5
# 7889714   2658896   206205    prior             2          2
# 7889715   2658896   206205    prior             2          2
# 7889716    969311   206205    prior             1          4
# 7889717    969311   206205    prior             1          4
#
#          order_hour_of_day  days_since_prior_order  product_id  \
# 0                       19                     9.0       248.0
# 1                       16                    17.0      1005.0
# 2                       18                    20.0      1819.0
# 3                       16                     7.0      1819.0
# 4                       15                     7.0      1819.0
# ...                    ...                     ...         ...
# 7889713                 16                    10.0     43352.0
# 7889714                 15                    30.0     44471.0
# 7889715                 15                    30.0     46820.0
# 7889716                 12                     NaN     49235.0
# 7889717                 12                     NaN     49628.0
#
#          add_to_cart_order  reordered  \
# 0                      3.0        0.0
# 1                      5.0        0.0
# 2                      1.0        0.0
# 3                      5.0        1.0
# 4                      2.0        1.0
# ...                    ...        ...
# 7889713                3.0        1.0
# 7889714                4.0        0.0
# 7889715                7.0        0.0
# 7889716                4.0        0.0
# 7889717               16.0        0.0
#
#                                      product_name  aisle_id  department_id  \
# 0                     Dried Sweetened Cranberries     117.0           19.0
# 1                      China Green Tips Green Tea      94.0            7.0
# 2        All Natural No Stir Creamy Almond Butter      88.0           13.0
# 3        All Natural No Stir Creamy Almond Butter      88.0           13.0
# 4        All Natural No Stir Creamy Almond Butter      88.0           13.0
# ...                                           ...       ...            ...
# 7889713                               Raspberries      32.0            4.0
# 7889714         Free & Clear Unscented Baby Wipes      82.0           18.0
# 7889715                  Vanilla Pure Almond Milk      91.0           16.0
# 7889716                       Organic Half & Half      53.0           16.0
# 7889717                         Yoghurt Blueberry     120.0           16.0
#
#                           aisle  department  days_cumsum
# 0        nuts seeds dried fruit      snacks          9.0
# 1                           tea   beverages        107.0
# 2                       spreads      pantry         50.0
# 3                       spreads      pantry         69.0
# 4                       spreads      pantry         76.0
# ...                         ...         ...          ...
# 7889713        packaged produce     produce         40.0
# 7889714        baby accessories      babies         30.0
# 7889715         soy lactosefree  dairy eggs         30.0
# 7889716                   cream  dairy eggs          0.0
# 7889717                  yogurt  dairy eggs          0.0
#
# [7889718 rows x 16 columns]

# %% [markdown]
# ## days since last bought of this product

# %%
days_diff = sample_order_prior.groupby(['user_id', 'product_id'])['days_cumsum'].diff()
days_diff
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3          19.0
# 4           7.0
#            ...
# 7889713    40.0
# 7889714     NaN
# 7889715     NaN
# 7889716     NaN
# 7889717     NaN
# Name: days_cumsum, Length: 7889718, dtype: float64

# %%
sample_order_prior['days_last_bought_product'] = days_diff
sample_order_prior.head(30)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0     444309        3    prior             2          3                 19
# 1     676467        3    prior            10          3                 16
# 2    2037211        3    prior             4          2                 18
# 3    1972919        3    prior             6          0                 16
# 4    1839752        3    prior             7          0                 15
# 5    3002854        3    prior             3          3                 16
# 6     444309        3    prior             2          3                 19
# 7    1374495        3    prior             1          1                 14
# 8    2037211        3    prior             4          2                 18
# 9    2710558        3    prior             5          0                 17
# 10   1972919        3    prior             6          0                 16
# 11   1839752        3    prior             7          0                 15
# 12   2037211        3    prior             4          2                 18
# 13   1972919        3    prior             6          0                 16
# 14   1839752        3    prior             7          0                 15
# 15   1374495        3    prior             1          1                 14
# 16   1374495        3    prior             1          1                 14
# 17   1839752        3    prior             7          0                 15
# 18   3160850        3    prior             9          0                 16
# 19   2037211        3    prior             4          2                 18
# 20   2710558        3    prior             5          0                 17
# 21   1374495        3    prior             1          1                 14
# 22    444309        3    prior             2          3                 19
# 23   2710558        3    prior             5          0                 17
# 24    676467        3    prior            10          3                 16
# 25    521107        3    prior            11          0                 18
# 26   2710558        3    prior             5          0                 17
# 27   1839752        3    prior             7          0                 15
# 28   3225766        3    prior             8          0                 17
# 29    676467        3    prior            10          3                 16
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      9.0       248.0                3.0        0.0
# 1                     17.0      1005.0                5.0        0.0
# 2                     20.0      1819.0                1.0        0.0
# 3                      7.0      1819.0                5.0        1.0
# 4                      7.0      1819.0                2.0        1.0
# 5                     21.0      7503.0                6.0        0.0
# 6                      9.0      8021.0                5.0        0.0
# 7                      NaN      9387.0                1.0        0.0
# 8                     20.0      9387.0                3.0        1.0
# 9                     12.0      9387.0                2.0        1.0
# 10                     7.0      9387.0                3.0        1.0
# 11                     7.0      9387.0                9.0        1.0
# 12                    20.0     12845.0                2.0        0.0
# 13                     7.0     14992.0                7.0        0.0
# 14                     7.0     14992.0                7.0        1.0
# 15                     NaN     15143.0                3.0        0.0
# 16                     NaN     16797.0                4.0        0.0
# 17                     7.0     16797.0                5.0        1.0
# 18                     7.0     16797.0                3.0        1.0
# 19                    20.0     16965.0                4.0        0.0
# 20                    12.0     16965.0                5.0        1.0
# 21                     NaN     17668.0                2.0        0.0
# 22                     9.0     17668.0                6.0        1.0
# 23                    12.0     17668.0                3.0        1.0
# 24                    17.0     17668.0                2.0        1.0
# 25                    11.0     17668.0                5.0        1.0
# 26                    12.0     18370.0               10.0        0.0
# 27                     7.0     18599.0                8.0        0.0
# 28                     7.0     18599.0                4.0        1.0
# 29                    17.0     18599.0                1.0        1.0
#
#                                        product_name  aisle_id  department_id  \
# 0                       Dried Sweetened Cranberries     117.0           19.0
# 1                        China Green Tips Green Tea      94.0            7.0
# 2          All Natural No Stir Creamy Almond Butter      88.0           13.0
# 3          All Natural No Stir Creamy Almond Butter      88.0           13.0
# 4          All Natural No Stir Creamy Almond Butter      88.0           13.0
# 5                                     Whole Almonds     117.0           19.0
# 6                        100% Recycled Paper Towels      54.0           17.0
# 7                               Granny Smith Apples      24.0            4.0
# 8                               Granny Smith Apples      24.0            4.0
# 9                               Granny Smith Apples      24.0            4.0
# 10                              Granny Smith Apples      24.0            4.0
# 11                              Granny Smith Apples      24.0            4.0
# 12                                  Chopped Walnuts     117.0           19.0
# 13                                      Green Beans      83.0            4.0
# 14                                      Green Beans      83.0            4.0
# 15                                   Blueberry Pint      24.0            4.0
# 16                                     Strawberries      24.0            4.0
# 17                                     Strawberries      24.0            4.0
# 18                                     Strawberries      24.0            4.0
# 19                              Chocolate Ice Cream      37.0            1.0
# 20                              Chocolate Ice Cream      37.0            1.0
# 21  Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 22  Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 23  Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 24  Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 25  Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 26                      Organic Shredded Mozzarella      21.0           16.0
# 27                                  Garlic Couscous       4.0            9.0
# 28                                  Garlic Couscous       4.0            9.0
# 29                                  Garlic Couscous       4.0            9.0
#
#                      aisle       department  days_cumsum  \
# 0   nuts seeds dried fruit           snacks          9.0
# 1                      tea        beverages        107.0
# 2                  spreads           pantry         50.0
# 3                  spreads           pantry         69.0
# 4                  spreads           pantry         76.0
# 5   nuts seeds dried fruit           snacks         30.0
# 6              paper goods        household          9.0
# 7             fresh fruits          produce          0.0
# 8             fresh fruits          produce         50.0
# 9             fresh fruits          produce         62.0
# 10            fresh fruits          produce         69.0
# 11            fresh fruits          produce         76.0
# 12  nuts seeds dried fruit           snacks         50.0
# 13        fresh vegetables          produce         69.0
# 14        fresh vegetables          produce         76.0
# 15            fresh fruits          produce          0.0
# 16            fresh fruits          produce          0.0
# 17            fresh fruits          produce         76.0
# 18            fresh fruits          produce         90.0
# 19           ice cream ice           frozen         50.0
# 20           ice cream ice           frozen         62.0
# 21         soy lactosefree       dairy eggs          0.0
# 22         soy lactosefree       dairy eggs          9.0
# 23         soy lactosefree       dairy eggs         62.0
# 24         soy lactosefree       dairy eggs        107.0
# 25         soy lactosefree       dairy eggs        118.0
# 26         packaged cheese       dairy eggs         62.0
# 27           instant foods  dry goods pasta         76.0
# 28           instant foods  dry goods pasta         83.0
# 29           instant foods  dry goods pasta        107.0
#
#     days_last_bought_product
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                       19.0
# 4                        7.0
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                       50.0
# 9                       12.0
# 10                       7.0
# 11                       7.0
# 12                       NaN
# 13                       NaN
# 14                       7.0
# 15                       NaN
# 16                       NaN
# 17                      76.0
# 18                      14.0
# 19                       NaN
# 20                      12.0
# 21                       NaN
# 22                       9.0
# 23                      53.0
# 24                      45.0
# 25                      11.0
# 26                       NaN
# 27                       NaN
# 28                       7.0
# 29                      24.0

# %%
order_diff = sample_order_prior.groupby(['user_id', 'product_id'])['order_number'].diff()
order_diff
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          2.0
# 4          1.0
#           ...
# 7889713    2.0
# 7889714    NaN
# 7889715    NaN
# 7889716    NaN
# 7889717    NaN
# Name: order_number, Length: 7889718, dtype: float64

# %%
sample_order_prior['order_diff_last_bought_product'] = order_diff
sample_order_prior.head(30)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0     444309        3    prior             2          3                 19
# 1     676467        3    prior            10          3                 16
# 2    2037211        3    prior             4          2                 18
# 3    1972919        3    prior             6          0                 16
# 4    1839752        3    prior             7          0                 15
# 5    3002854        3    prior             3          3                 16
# 6     444309        3    prior             2          3                 19
# 7    1374495        3    prior             1          1                 14
# 8    2037211        3    prior             4          2                 18
# 9    2710558        3    prior             5          0                 17
# 10   1972919        3    prior             6          0                 16
# 11   1839752        3    prior             7          0                 15
# 12   2037211        3    prior             4          2                 18
# 13   1972919        3    prior             6          0                 16
# 14   1839752        3    prior             7          0                 15
# 15   1374495        3    prior             1          1                 14
# 16   1374495        3    prior             1          1                 14
# 17   1839752        3    prior             7          0                 15
# 18   3160850        3    prior             9          0                 16
# 19   2037211        3    prior             4          2                 18
# 20   2710558        3    prior             5          0                 17
# 21   1374495        3    prior             1          1                 14
# 22    444309        3    prior             2          3                 19
# 23   2710558        3    prior             5          0                 17
# 24    676467        3    prior            10          3                 16
# 25    521107        3    prior            11          0                 18
# 26   2710558        3    prior             5          0                 17
# 27   1839752        3    prior             7          0                 15
# 28   3225766        3    prior             8          0                 17
# 29    676467        3    prior            10          3                 16
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      9.0       248.0                3.0        0.0
# 1                     17.0      1005.0                5.0        0.0
# 2                     20.0      1819.0                1.0        0.0
# 3                      7.0      1819.0                5.0        1.0
# 4                      7.0      1819.0                2.0        1.0
# 5                     21.0      7503.0                6.0        0.0
# 6                      9.0      8021.0                5.0        0.0
# 7                      NaN      9387.0                1.0        0.0
# 8                     20.0      9387.0                3.0        1.0
# 9                     12.0      9387.0                2.0        1.0
# 10                     7.0      9387.0                3.0        1.0
# 11                     7.0      9387.0                9.0        1.0
# 12                    20.0     12845.0                2.0        0.0
# 13                     7.0     14992.0                7.0        0.0
# 14                     7.0     14992.0                7.0        1.0
# 15                     NaN     15143.0                3.0        0.0
# 16                     NaN     16797.0                4.0        0.0
# 17                     7.0     16797.0                5.0        1.0
# 18                     7.0     16797.0                3.0        1.0
# 19                    20.0     16965.0                4.0        0.0
# 20                    12.0     16965.0                5.0        1.0
# 21                     NaN     17668.0                2.0        0.0
# 22                     9.0     17668.0                6.0        1.0
# 23                    12.0     17668.0                3.0        1.0
# 24                    17.0     17668.0                2.0        1.0
# 25                    11.0     17668.0                5.0        1.0
# 26                    12.0     18370.0               10.0        0.0
# 27                     7.0     18599.0                8.0        0.0
# 28                     7.0     18599.0                4.0        1.0
# 29                    17.0     18599.0                1.0        1.0
#
#                                        product_name  aisle_id  department_id  \
# 0                       Dried Sweetened Cranberries     117.0           19.0
# 1                        China Green Tips Green Tea      94.0            7.0
# 2          All Natural No Stir Creamy Almond Butter      88.0           13.0
# 3          All Natural No Stir Creamy Almond Butter      88.0           13.0
# 4          All Natural No Stir Creamy Almond Butter      88.0           13.0
# 5                                     Whole Almonds     117.0           19.0
# 6                        100% Recycled Paper Towels      54.0           17.0
# 7                               Granny Smith Apples      24.0            4.0
# 8                               Granny Smith Apples      24.0            4.0
# 9                               Granny Smith Apples      24.0            4.0
# 10                              Granny Smith Apples      24.0            4.0
# 11                              Granny Smith Apples      24.0            4.0
# 12                                  Chopped Walnuts     117.0           19.0
# 13                                      Green Beans      83.0            4.0
# 14                                      Green Beans      83.0            4.0
# 15                                   Blueberry Pint      24.0            4.0
# 16                                     Strawberries      24.0            4.0
# 17                                     Strawberries      24.0            4.0
# 18                                     Strawberries      24.0            4.0
# 19                              Chocolate Ice Cream      37.0            1.0
# 20                              Chocolate Ice Cream      37.0            1.0
# 21  Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 22  Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 23  Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 24  Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 25  Unsweetened Chocolate Almond Breeze Almond Milk      91.0           16.0
# 26                      Organic Shredded Mozzarella      21.0           16.0
# 27                                  Garlic Couscous       4.0            9.0
# 28                                  Garlic Couscous       4.0            9.0
# 29                                  Garlic Couscous       4.0            9.0
#
#                      aisle       department  days_cumsum  \
# 0   nuts seeds dried fruit           snacks          9.0
# 1                      tea        beverages        107.0
# 2                  spreads           pantry         50.0
# 3                  spreads           pantry         69.0
# 4                  spreads           pantry         76.0
# 5   nuts seeds dried fruit           snacks         30.0
# 6              paper goods        household          9.0
# 7             fresh fruits          produce          0.0
# 8             fresh fruits          produce         50.0
# 9             fresh fruits          produce         62.0
# 10            fresh fruits          produce         69.0
# 11            fresh fruits          produce         76.0
# 12  nuts seeds dried fruit           snacks         50.0
# 13        fresh vegetables          produce         69.0
# 14        fresh vegetables          produce         76.0
# 15            fresh fruits          produce          0.0
# 16            fresh fruits          produce          0.0
# 17            fresh fruits          produce         76.0
# 18            fresh fruits          produce         90.0
# 19           ice cream ice           frozen         50.0
# 20           ice cream ice           frozen         62.0
# 21         soy lactosefree       dairy eggs          0.0
# 22         soy lactosefree       dairy eggs          9.0
# 23         soy lactosefree       dairy eggs         62.0
# 24         soy lactosefree       dairy eggs        107.0
# 25         soy lactosefree       dairy eggs        118.0
# 26         packaged cheese       dairy eggs         62.0
# 27           instant foods  dry goods pasta         76.0
# 28           instant foods  dry goods pasta         83.0
# 29           instant foods  dry goods pasta        107.0
#
#     days_last_bought_product  order_diff_last_bought_product
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                       19.0                             2.0
# 4                        7.0                             1.0
# 5                        NaN                             NaN
# 6                        NaN                             NaN
# 7                        NaN                             NaN
# 8                       50.0                             3.0
# 9                       12.0                             1.0
# 10                       7.0                             1.0
# 11                       7.0                             1.0
# 12                       NaN                             NaN
# 13                       NaN                             NaN
# 14                       7.0                             1.0
# 15                       NaN                             NaN
# 16                       NaN                             NaN
# 17                      76.0                             6.0
# 18                      14.0                             2.0
# 19                       NaN                             NaN
# 20                      12.0                             1.0
# 21                       NaN                             NaN
# 22                       9.0                             1.0
# 23                      53.0                             3.0
# 24                      45.0                             5.0
# 25                      11.0                             1.0
# 26                       NaN                             NaN
# 27                       NaN                             NaN
# 28                       7.0                             1.0
# 29                      24.0                             2.0

# %%
sample_order_prior.to_csv("instacart/sample_order_prior_diff.csv", index=False)

# %%
sample_order_train.to_csv("instacart/sample_order_train_cumsum.csv", index=False)
sample_order_test.to_csv("instacart/sample_order_test_cumsum.csv", index=False)

# %% [markdown]
# ## Aggregate features for user x product

# %%
sample_order_prior['order_hour_of_day'].mode()[0]
# Out:
# 10

# %%
sample_order_prior_user_product = sample_order_prior.groupby(['user_id', 'product_id']).agg(
    days_cumsum=('days_cumsum', 'last'),
    num_prod_bought=('order_number', 'count'),
    days_since_last_bought=('days_last_bought_product', 'last'),
    average_days_period=('days_last_bought_product', 'mean'),
    orders_since_last_bought=('order_diff_last_bought_product', 'last'),
    average_orders_period=('order_diff_last_bought_product', 'mean'),
    dow_usually_bought=('order_dow', lambda x: x.mode()[0]),
    hod_usually_bought=('order_hour_of_day', lambda x: x.mode()[0]),
    department_id=('department_id', 'last'),
    aisle_id=('aisle_id', 'last'))

# %%
sample_order_prior_user_product
# Out:
#                     days_cumsum  num_prod_bought  days_since_last_bought  \
# user_id product_id
# 3       248.0               9.0                1                     NaN
#         1005.0            107.0                1                     NaN
#         1819.0             76.0                3                     7.0
#         7503.0             30.0                1                     NaN
#         8021.0              9.0                1                     NaN
# ...                         ...              ...                     ...
# 206205  43352.0            40.0                2                    40.0
#         44471.0            30.0                1                     NaN
#         46820.0            30.0                1                     NaN
#         49235.0             0.0                1                     NaN
#         49628.0             0.0                1                     NaN
#
#                     average_days_period  orders_since_last_bought  \
# user_id product_id
# 3       248.0                       NaN                       NaN
#         1005.0                      NaN                       NaN
#         1819.0                     13.0                       1.0
#         7503.0                      NaN                       NaN
#         8021.0                      NaN                       NaN
# ...                                 ...                       ...
# 206205  43352.0                    40.0                       2.0
#         44471.0                     NaN                       NaN
#         46820.0                     NaN                       NaN
#         49235.0                     NaN                       NaN
#         49628.0                     NaN                       NaN
#
#                     average_orders_period  dow_usually_bought  \
# user_id product_id
# 3       248.0                         NaN                   3
#         1005.0                        NaN                   3
#         1819.0                        1.5                   0
#         7503.0                        NaN                   3
#         8021.0                        NaN                   3
# ...                                   ...                 ...
# 206205  43352.0                       2.0                   4
#         44471.0                       NaN                   2
#         46820.0                       NaN                   2
#         49235.0                       NaN                   4
#         49628.0                       NaN                   4
#
#                     hod_usually_bought  department_id  aisle_id
# user_id product_id
# 3       248.0                       19           19.0     117.0
#         1005.0                      16            7.0      94.0
#         1819.0                      15           13.0      88.0
#         7503.0                      16           19.0     117.0
#         8021.0                      19           17.0      54.0
# ...                                ...            ...       ...
# 206205  43352.0                     12            4.0      32.0
#         44471.0                     15           18.0      82.0
#         46820.0                     15           16.0      91.0
#         49235.0                     12           16.0      53.0
#         49628.0                     12           16.0     120.0
#
# [3231752 rows x 10 columns]

# %%
sample_order_prior_user_product.to_csv("instacart/sample_order_prior_user_product.csv")

# %% [markdown]
# ## Aggregate features for user x department

# %%
sample_order_prior['department_id'].nunique()
# Out:
# 21

# %%
sample_order_prior_user_department = sample_order_prior.groupby(['user_id', 'department_id']).agg(
    num_prod_bought_dep=('add_to_cart_order', 'count'),
    num_order_bought_dep=('order_number', 'nunique')
)
sample_order_prior_user_department
# Out:
#                        num_prod_bought_dep  num_order_bought_dep
# user_id department_id
# 3       1.0                              6                     5
#         4.0                             38                    12
#         7.0                              3                     3
#         9.0                              4                     4
#         13.0                             4                     4
# ...                                    ...                   ...
# 206205  12.0                             1                     1
#         16.0                            14                     3
#         18.0                             1                     1
#         20.0                             3                     1
#         21.0                             1                     1
#
# [541778 rows x 2 columns]

# %%
sample_order_prior_user_department.to_csv("instacart/sample_order_prior_user_department.csv")

# %% [markdown]
# ## Aggregate features for user x aisle

# %%
sample_order_prior_user_aisle = sample_order_prior.groupby(['user_id', 'aisle_id']).agg(
    num_prod_bought_ais=('add_to_cart_order', 'count'),
    num_order_bought_ais=('order_number', 'nunique')
)
sample_order_prior_user_aisle
# Out:
#                   num_prod_bought_ais  num_order_bought_ais
# user_id aisle_id
# 3       4.0                         4                     4
#         13.0                        2                     2
#         21.0                        5                     4
#         24.0                       19                    12
#         37.0                        4                     4
# ...                               ...                   ...
# 206205  98.0                        1                     1
#         100.0                       1                     1
#         112.0                       2                     2
#         116.0                       1                     1
#         120.0                       5                     2
#
# [1390425 rows x 2 columns]

# %%
sample_order_prior_user_aisle.to_csv("instacart/sample_order_prior_user_aisle.csv")

# %% [markdown]
# ## Aggregate features for user

# %%
sample_order_prior.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'aisle', 'department', 'days_cumsum',
#        'days_last_bought_product', 'order_diff_last_bought_product'],
#       dtype='object')

# %%
sample_order_prior_user = sample_order_prior[['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
       'order_hour_of_day', 'days_since_prior_order', 'days_cumsum']].sort_values(
    by=['user_id', 'order_number']
).drop_duplicates().reset_index(drop=True)

sample_order_prior_user
# Out:
#         order_id  user_id eval_set  order_number  order_dow  \
# 0        1374495        3    prior             1          1
# 1         444309        3    prior             2          3
# 2        3002854        3    prior             3          3
# 3        2037211        3    prior             4          2
# 4        2710558        3    prior             5          0
# ...          ...      ...      ...           ...        ...
# 780591   1869536   206202    prior            21          4
# 780592   1112560   206202    prior            22          3
# 780593    969311   206205    prior             1          4
# 780594   2658896   206205    prior             2          2
# 780595    414137   206205    prior             3          5
#
#         order_hour_of_day  days_since_prior_order  days_cumsum
# 0                      14                     NaN          0.0
# 1                      19                     9.0          9.0
# 2                      16                    21.0         30.0
# 3                      18                    20.0         50.0
# 4                      17                    12.0         62.0
# ...                   ...                     ...          ...
# 780591                  0                    30.0        263.0
# 780592                 14                     6.0        269.0
# 780593                 12                     NaN          0.0
# 780594                 15                    30.0         30.0
# 780595                 16                    10.0         40.0
#
# [780596 rows x 8 columns]

# %%
sample_order_prior_user = sample_order_prior_user.groupby(['user_id']).agg(
    number_user_order=('order_number', max),
    dow_user_usually_bought=('order_dow', lambda x: x.mode()[0]),
    hod_user_usually_bought=('order_hour_of_day', lambda x: x.mode()[0]),
    days_cumsum_last=('days_cumsum', 'last'),
    average_daydiff_user=('days_since_prior_order', 'mean')
)
sample_order_prior_user
# Out:
#          number_user_order  dow_user_usually_bought  hod_user_usually_bought  \
# user_id
# 3                       12                        0                       16
# 5                        4                        3                       18
# 13                      12                        6                       12
# 25                       3                        1                       14
# 29                      18                        5                       11
# ...                    ...                      ...                      ...
# 206189                   6                        0                       15
# 206191                   5                        0                        9
# 206195                  19                        6                        9
# 206202                  22                        4                        0
# 206205                   3                        2                       12
#
#          days_cumsum_last  average_daydiff_user
# user_id
# 3                   133.0             12.090909
# 5                    40.0             13.333333
# 13                   84.0              7.636364
# 25                   60.0             30.000000
# 29                  196.0             11.529412
# ...                   ...                   ...
# 206189               80.0             16.000000
# 206191               78.0             19.500000
# 206195              122.0              6.777778
# 206202              269.0             12.809524
# 206205               40.0             20.000000
#
# [50000 rows x 5 columns]

# %%
sample_order_prior_user.to_csv("instacart/sample_order_prior_user.csv")
